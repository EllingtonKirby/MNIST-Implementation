# %% [markdown]
# <a href="https://colab.research.google.com/github/EllingtonKirby/Workbooks/blob/master/Allosaurus_test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install torchaudio

import torchaudio
from torchaudio import datasets
from IPython.display import Audio

# %%
data = datasets.CMUARCTIC(root=".", download=True, folder_in_archive="ARCTIC", url="aew")

# %%
n = 0
(waveform, sample_rate, utterance, utterance_id) = data.__getitem__(10)

wave_dir = '.'
wave_filename = f'{wave_dir}/{utterance_id}.wav'
torchaudio.save(wave_filename, waveform, sample_rate, bits_per_sample=16)

# %%
audio = Audio(data=waveform, rate=sample_rate)
audio
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
from allosaurus.app import read_recognizer
allo_model = read_recognizer()

# %%
# %%timeit
allo_model.recognize(wave_filename)
# Out:
# 1 loop, best of 5: 319 ms per loop
